# %% [markdown]
# # Class 0: Introduction to the Course, Github, Computing Setup

# %% [markdown]
# Goal of today's class:
# 1. Introduce the syllabus
# 2. Ensure we're all on the Explorer Cluster
# 3. Set up classroom virtual environment

# %% [markdown]
# ## Welcome to PHYS/NETS 7052 — Computational Methods for Network Science

# %% [markdown]
# _________________

# %% [markdown]
# ## How The Course Works
# This course offers an introduction to network analysis and is designed to provide students with an overview of the core data scientific skills required to analyze complex networks. Through hands-on lectures, labs, and projects, students will learn actionable skills about network analysis techniques using Python (in particular, the `networkx` library). The course covers network data collection, data input/output, network statistics, dynamics, and visualization. Students also learn about random graph models and algorithms for computing network properties like path lengths, clustering, degree distributions, and community structure. In addition, students will develop web scraping skills and will be introduced to the vast landscape of software tools for analyzing complex networks. The course ends with a large-scale final project that demonstrates the proficiency of the students in network analysis.
#
# This syllabus may be updated and can be found here: https://brennanklein.com/nets7052-fall26.
#
# This course has been built from the foundation of the years of work/development by Matteo Chinazzi and Qian Zhang, for earlier iterations of Network Science Data.
#
# ### Course Learning Outcomes
# 1. Develop and maintain software to analyze networks derived from a range of data sources, including real-world and simulated datasets.
# 2. Implement network algorithms to measure clustering, path lengths, spectra, community structure, and dynamics, demonstrating both theoretical understanding and computational proficiency.
# 3. Construct reproducible data analyses that integrate high-performance computing resources (e.g., the Explorer cluster at Northeastern University) for handling large-scale network data.
# 4. Design and code generative network models to simulate network growth, structure, and dynamics, and apply these models for inference from empirical data.
# 5. Collect network data online through web scraping, incorporating data collection ethics and norms.
# 6. Create and present pedagogical materials (e.g., a Jupyter Book chapter) on an advanced network analysis topic not covered in lectures, communicating technical ideas clearly to both specialist and non-specialist audiences.

# %% [markdown]
# ### Course Materials
# There are no required materials for this course, but we will periodically draw from:
# -  Bagrow & Ahn (2024). ***Working with Network Data: A Data Science Perspective***. Cambridge University Press; 1st Edition; 978-1009212595. https://www.cambridge.org/network-data.
#
# Additionally, we recommend engagement with other useful network science and/or Python materials:
# - Barabási (2016). ***Network Science***. Cambridge University Press; 1st Edition; 978-1107076266. http://networksciencebook.com/.
# - Newman (2018). ***Networks: An Introduction***. Oxford University Press; 2nd Edition; 978-0198805090. https://global.oup.com/academic/product/networks-9780198805090.
# - VanderPlas (2019). ***Python Data Science Handbook***. O'Reilly Media, Inc; 978-1491912058. https://github.com/jakevdp/PythonDataScienceHandbook.

# %% [markdown]
# ## Class Expectations
# This course is still evolving. It ran for the first time in Fall 2024 and again in Fall 2025 as PHYS 7332; this year it carries a new number and is the required computational methods course for the Network Science PhD program. Each iteration has changed based on what worked and what didn't, and the material is now becoming a textbook. So I'll be asking for feedback constantly — on assignments, on pacing, on which topics deserve more room. Tell me a class went too fast and the next one slows down.
#
# ### Classroom Interactions
# This is largely a coding course. We'll all have our computers out, following along in the same notebook I'm teaching from. There will be frequent "your turn!" sections, where you break off solo or in small teams to solve an in-class challenge. When we come back together, I'll ask for volunteers to share their screen and show off what they've done.

# %% [markdown]
# ## Coursework, Class Structure, Grading
# Grading in this course will be as follows:
# - Class Attendance & Participation: 10%
# - Problem Sets: 45%
# - Mid-Semester Project Presentation: 15%
# - Final Project — Presentation & Report: 30%
#
# ### Final Project
# The final project for this course is a chance for students to synthesize their knowledge of network analysis into pedagogical materials around a topic of their choosing. Modeled after chapters in the Jupyter book for this course, students will be required to make a new "chapter" for our class's textbook; this requires creating a thoroughly documented, informative Python notebook that explains an *advanced* topic that was not deeply explored in the course. For these projects, students are required to conduct their own research into the background of the technique, the original paper(s) introducing the topic, and how/if it is currently used in today's network analysis literature. Students will demonstrate that they have mastered this technique by using informative data for illustrating the usefulness of the topic they've chosen. Every chapter should contain informative data visualizations that build on one another, section-by-section. The purpose of this assignment is to demonstrate the coding skills gained in this course, doing so by learning a new network analysis technique and sharing it with members of the class. Over time, these lessons may find their way into the curriculum for future iterations of this class. Halfway through the semester, there will be project update presentations where students receive class and instructor feedback on their project topics. Throughout, I am available to brainstorm project ideas with you.
#
# #### Ideas for Final Project Chapters (non-exhaustive):
# 1. Motifs in Networks
# 2. Robustness / Resilience of Network Structure
# 3. Network Game Theory
# 4. Network Geometry
# 5. Continuous Models of Network Dynamics
# 6. Percolation in Networks
# 7. Signed Networks
# 8. Coarse Graining Networks
# 9. Mesoscale Structure in Networks (e.g. core-periphery)
# 10. Graph Isomorphism and Approximate Isomorphism
# 11. Higher-Order Networks
# 12. Introduction to Graph Neural Networks
# 13. Hopfield Networks and Boltzmann Machines
# 14. Graph Curvature or Topology
# 15. Reservoir Computing
# 16. Adaptive Networks
# 17. Multiplex/Multilayer Networks
# 18. Network Rewiring Dynamics
# 19. Fitting Distributions to Network Data
# 20. Hierarchical Networks
# 21. Ranking in Networks
# 22. Deeper Dive: Random Walks on Networks
# 23. Deeper Dive: Directed Networks
# 24. Deeper Dive: Network Null Models
# 25. Deeper Dive: Network Paths and their Statistics
# 26. Deeper Dive: Network Growth Models
# 27. Deeper Dive: Hypothesis Testing in Social Networks
# 28. Deeper Dive: Bipartite Networks
# 29. Many more possible ideas!
#
# ___________________

# %% [markdown]
# ## What You'll Learn
# Students should leave this class with an ever-growing codebase of resources for analyzing and deriving insights from complex networks, using Python. These skills range from being able to (from scratch) code algorithms on graphs, including path length calculations, network sampling, dynamical processes, and network null models; as well as interfacing with standard data science questions around storing, querying, and analyzing large complex datasets.
#
# ### Schedule
#
# | DATE | CLASS |
# | --- | --- |
# | Mon, Sep 7, 26 | **Labor Day** — no class |
# | Wed, Sep 9, 26 | **Class 0:** Introduction to the Course, GitHub, Computing Setup |
# | | |
# | Mon, Sep 14, 26 | **Class 1:** Python Refresher (Data Structures, NumPy) |
# | Wed, Sep 16, 26 | **Class 2:** Introduction to NetworkX 1 — Loading Data, Basic Statistics |
# | Fri, Sep 18, 26 | *Assignment 1 announced* |
# | | |
# | Mon, Sep 21, 26 | **Class 3:** Introduction to NetworkX 2 — Graph Algorithms |
# | Wed, Sep 23, 26 | **Class 4:** Distributions of Network Properties & Centralities |
# | | |
# | Mon, Sep 28, 26 | **Class 5:** Scraping Web Data — BeautifulSoup, HTML, Pandas |
# | Wed, Sep 30, 26 | **Class 6:** Data Science & SQL |
# | Fri, Oct 2, 26 | **Assignment 1 due** |
# | | |
# | Mon, Oct 5, 26 | **Class 7:** Clustering & Community Detection 1 — Traditional |
# | Wed, Oct 7, 26 | **Class 8:** Clustering & Community Detection 2 — Contemporary |
# | Fri, Oct 9, 26 | *Assignment 2 announced* |
# | | |
# | Mon, Oct 12, 26 | **Indigenous Peoples Day** — no class |
# | Wed, Oct 14, 26 | **Class 9:** Guest Speaker |
# | | |
# | Mon, Oct 19, 26 | **Class 10:** Project Update Presentations |
# | Wed, Oct 21, 26 | **Class 11:** Visualization — Python |
# | Fri, Oct 23, 26 | **Assignment 2 due** |
# | | |
# | Mon, Oct 26, 26 | **Class 12:** Introduction to Machine Learning 1 — General |
# | Wed, Oct 28, 26 | **Class 13:** Introduction to Machine Learning 2 — Networks |
# | Fri, Oct 30, 26 | *Assignment 3 announced* |
# | | |
# | Mon, Nov 2, 26 | **Class 14:** Dynamics on Networks 1 — Diffusion and Random Walks |
# | Wed, Nov 4, 26 | **Class 15:** Dynamics on Networks 2 — Compartmental Models |
# | | |
# | Mon, Nov 9, 26 | **Class 16:** Dynamics on Networks 3 — Agent-Based Models |
# | Wed, Nov 11, 26 | **Veterans Day** — no class |
# | Fri, Nov 13, 26 | **Assignment 3 due** |
# | | |
# | Mon, Nov 16, 26 | **Class 17:** Network Sampling |
# | Wed, Nov 18, 26 | **Class 18:** Network Filtering / Thresholding |
# | | |
# | Mon, Nov 23, 26 | **Class 19:** Dynamics of Networks — Temporal Networks |
# | Wed, Nov 25, 26 | **Fall Break** — no class |
# | | |
# | Mon, Nov 30, 26 | **Class 20:** Network Comparison & Graph Distances |
# | Wed, Dec 2, 26 | **Class 21:** Network Reconstruction from Dynamics |
# | | |
# | Mon, Dec 7, 26 | **Class 22:** Spatial Data, OSMNX, GeoPandas |
# | Wed, Dec 9, 26 | **Class 23:** Final Presentation — Office Hours |
# | | |
# | Mon, Dec 14, 26 | **Class 24:** Final Presentations 1 |
# | Wed, Dec 16, 26 | **Class 25:** Final Presentations 2 |

# %% [markdown]
# ________________

# %% [markdown]
# ## Explorer Cluster
#
# From Research Computing at Northeastern: "The Northeastern University HPC Cluster is a high-powered, multi-node, parallel computing system designed to meet the computational and data-intensive needs of various academic and industry-oriented research projects. The cluster incorporates cutting-edge computing technologies and robust storage solutions, providing an efficient and scalable environment for large-scale simulations, complex calculations, artificial intelligence, machine learning, big data analytics, bioinformatics, and more.
#
# Whether you are a seasoned user or just beginning your journey into high-performance computing, our portal offers comprehensive resources, including in-depth guides, tutorials, best practices, and troubleshooting tips. Furthermore, the platform provides a streamlined interface to monitor, submit, and manage your computational jobs on the HPC cluster.
#
# We invite you to explore the resources, tools, and services available through the portal. Join us as we endeavor to harness the power of high-performance computing, enabling breakthroughs in research and fostering innovation at Northeastern University." (https://rc-docs.northeastern.edu/en/latest/index.html)
#
#
# ### Documentation:
# - Getting started: https://rc-docs.northeastern.edu/en/explorer-main/
#
# ### Trainings:
# - Video and tutorial files for getting started on the Explorer cluster: https://rc.northeastern.edu/support/training/

# %% [markdown]
# ### Open OnDemand (OOD)
# "Open OnDemand empowers students, researchers, and industry professionals with remote web access to supercomputers." (https://openondemand.org/)
#
# Open OnDemand is a software platform that provides an easy-to-use web interface for accessing and managing high-performance computing (HPC) resources. It simplifies the process of submitting jobs, managing files, and running interactive applications on HPC systems without the need for complex command-line interactions. For the class this fall, we'll be using Open OnDemand to give students hands-on experience with HPC resources, letting us run simulations, analyze large datasets, and explore computational tools in a user-friendly environment. This is designed to let students focus on learning and applying computational techniques without getting bogged down by technical complexities.
#
#
# ![](images/ood_home_screen.png)
# __________________
# #### Interacting with OOD
#
# Open OnDemand Documentation: https://osc.github.io/ood-documentation/latest/
# ________________

# %% [markdown]
# **Standard Apps:**
# ![](images/ood_home_standardapps_tab.png)

# %% [markdown]
# _____
#
# **Specialized Apps:**
# ![](images/ood_home_specializedapps_tab.png)
#
# _____________

# %% [markdown]
# **Courses:**
# ![](images/ood_home_courses_tab.png)

# %% [markdown]
# ___________
# ### Our Very Own Partition
# ![](images/explorer_classroom_integration.png)
# _________________

# %% [markdown]
# ### Jupyter Notebook Server
# This is the one you'll live in. You ask for some CPUs and some memory, it finds you a node on the `courses` partition, and it's yours for up to 24 hours. Every notebook in this class runs here.
#
# Don't launch it yet — we'll do that together once your fork is cloned.

# %% [markdown]
# ### Virtual Environment
# #### What is `conda` and why do we use it?
# Python has the ability to do a lot of things on its own, but sometimes we need to install *packages* that extend Python's functionality. For example, `scikit-learn` has a lot of machine learning algorithms, and `geopy` does handy geographic math (like calculating geodesic distances). Managing the dependencies these packages have on other packages is really annoying and really easy to mess up ([in fact, it is NP-complete,](https://stackoverflow.com/questions/28099683/algorithm-for-dependency-resolution), which means it's a very hard type of computational problem), so we use tools called *package managers*. `pip` is one package manager, and `conda` is a fancier one. `conda`, short for `anaconda`, can handle packages that are outside the Python ecosystem, like C compilers, whereas `pip` cannot.
#
# #### Class Virtual Environment
# Our class has a shared virtual environment that you can access once you use `module` to load `conda`. `module` is a tool that's frequently used on computing clusters to load software packages on demand. [Here's](https://rc-docs.northeastern.edu/en/latest/software/packagemanagers/conda.html) some information on loading `conda` on Explorer, and [here's](https://rc-docs.northeastern.edu/en/latest/software/systemwide/modules.html) some information on `module`. First, you need to request a compute node on Explorer. We'll go to Open On Demand ([https://ood.explorer.northeastern.edu/](https://ood.explorer.northeastern.edu/)) and open up an interactive shell:
# ![opening an interactive shell](images/ood_terminal_screenshot.png)
#
# Once you're in the interactive shell, request a compute node:
#
# `srun --partition=courses --nodes=1 --cpus-per-task=2 --mem=8G --time=03:00:00 --pty /bin/bash`
#
# Your prompt will change from `login` to a compute node name (something like `c3014`) — that is how you know it worked.
#
# Next, load `conda` and activate the class environment:
#
# `module load anaconda3/2024.06`
#
# `source /shared/EL9/explorer/anaconda3/2024.06/etc/profile.d/conda.sh`
#
# `conda activate /courses/NETS7052.202710/shared/cmns-core`
#
# Check that it worked:
#
# `which python`
#
# You should see `/courses/NETS7052.202710/shared/cmns-core/bin/python`. If you see a path starting with `/shared/EL9/...` instead, the environment didn't activate — run the `source` and `conda activate` lines again. If it still doesn't take, tell me and we'll fix it now.
#
# ```{note}
# You'll also see `source activate <path>` used for this, including in RC's own docs linked above. We use `conda activate` here because when I set this environment up, `source activate` left my prompt looking right while `python` still pointed at the system install — and that surfaces much later as a baffling `numpy` error. Whichever you use, `which python` is the check that catches it.
# ```

# %% [markdown]
# _________

# %% [markdown]
# ## GitHub
# ### What is GitHub?
# GitHub is a website that implements `git`.
#
# `git` is a piece of open-source software that does distributed version control. This is really important for big teams making changes simultaneously to a large codebase. Git lets people document and track their code, and its various versions, so they can collaborate more efficiently.
#
# On Github, you'll keep your code in what's called a *repository*. That's a chunk of code that all works together. You can download a repository to your own computer, make changes to it, and *push* them to the repository on GitHub. Then your changes will be reflected in the version of the repository that's on GitHub, and anyone can download the version with your changes in it.
#
# Our class has a repository that's available at [**https://github.com/computational-methods-network-science/nets7052_fa26/**](https://github.com/computational-methods-network-science/nets7052_fa26/). You will download a *fork* of the repository to make your very own. Occasionally we'll update the repository and you'll need to incorporate the updates; we'll explain how to do that in a second.
#
# ![a screenshot of the github repo with fork command](images/github_class_screen.png)

# %% [markdown]
# ### Forking and Maintaining The Class Repository
# First, let's fork the repository. Go to the repository GitHub link. You'll see a button in the top right that says "Fork". Click on it:
# ![a screenshot of the github repo with fork command](images/github_create_fork_screen.png)

# %% [markdown]
# Once you've clicked the fork button, you'll get this screen:
#
# ![a screenshot of fork creation](images/github_fork_screenshot.png)
# Make sure you're listed as the owner and create the fork.
#
# #### Why fork instead of just cloning?
#
# You could clone my repository directly and get all the same files. But you'd have no way to push anything back, because you don't have write access to my copy — and you wouldn't want it. A whole class committing to one repository would collide constantly.
#
# A fork is your own copy of the repository *on GitHub*, under your account, that you own outright. So the chain is: my repo, then your fork on GitHub, then your clone on Explorer where you actually work. You can commit and push to your fork as much as you like without touching mine or anyone else's. The `upstream` remote we set up next is the one-way channel that lets my updates flow down to you.
#
# When the semester ends, your fork stays yours — notebooks, notes, and all.

# %% [markdown]
# Then you'll clone your fork in the Explorer terminal using the URL obtained via the green `Code` button:
# ![a screenshot of the clone button](images/github_clone_repo.png)
#
# We're going to first navigate to your folder in our course partition:
#
# `cd /courses/NETS7052.202710/students/USERNAME` where `USERNAME` is your Northeastern username. Then we'll clone the repo:
#
# `git clone [URL YOU COPIED]`
#
# Now let's set up a way to get updates from the original repo. Let's `cd` into the repo:
# `cd REPO_FILEPATH`
#
# `git remote add upstream https://github.com/computational-methods-network-science/nets7052_fa26.git`
#
# `git fetch upstream`
#
# `git checkout main`
#
# `git merge upstream/main`
#
#
# This sets up the original version of the GitHub repo as an upstream source. Now we can, at any point, fetch the upstream source and merge it into our main branch, which is the main branch of your forked repository. You'll be working in this forked repository in your `/courses/NETS7052.202710/students/USERNAME` directory throughout the course. If you want to sync your forked version with the original version (as we will be adding new notebooks over the course of the class), you can run the following commands:
#
# `git fetch upstream`
#
# `git checkout main`
#
# `git merge upstream/main`
#
# (Here's a [StackOverflow thread](https://stackoverflow.com/questions/7244321/how-do-i-update-or-sync-a-forked-repository-on-github) explaining this in more detail.)
# ______

# %% [markdown]
# ### Starting a JupyterLab instance
# Recall from earlier, the "Courses" tab:
# ![](images/ood_home_courses_tab.png)

# %% [markdown]
# Click on that, then fill in the following information (after you do this once, it'll auto-populate for future classes). Heads up: that screenshot is from last year's version of the course, so the working directory and the memory in it are wrong — use the values in the table.
# ![](images/ood_launch_jupyter.png)
#
# For this class, fill the form in like this:
#
# | Field | Value |
# |---|---|
# | System-wide Conda Module | `anaconda3/2024.06` |
# | Local Anaconda install | leave unchecked |
# | Custom Anaconda Environment | **leave unchecked** (see below) |
# | Working Directory | `/courses/NETS7052.202710/students/USERNAME` (your NU username) |
# | Partition | `courses` |
# | Time (Hours) | `4` |
# | CPUs | `2` |
# | Memory (GB) | `8` |
#
# Why 4 hours for a 100-minute class? If your session expires mid-class you lose your running kernel and start over from the top. The CPU and memory numbers go the other way — bigger requests sit longer in the queue, and nothing we do this semester needs more than 2 CPUs and 8 GB.
#
# #### Registering the class environment as a kernel (do this once)
#
# Notice that "Custom Anaconda Environment" is a checkbox, not a text field. Tick it and you get a box that wants an environment *name* — and ours is identified by a *path*, so it can never point at our environment. Leave it unchecked and register the environment as a Jupyter kernel instead. You only do this once; afterwards it shows up in the kernel menu of every notebook you open.
#
# Once JupyterLab has started, open a terminal (**File → New → Terminal**) and run this single line, exactly as written:
#
# ```bash
# /courses/NETS7052.202710/shared/cmns-core/bin/python -m ipykernel install --user --name cmns-core --display-name "Python (cmns-core)"
# ```
#
# Calling the environment's Python by its full path matters. If you activate the environment first and then run plain `python`, you can end up registering a kernel that is *named* `cmns-core` but still points at the system Python — which produces the NumPy error described below even though the kernel menu looks right.
#
# You can check what you registered:
#
# ```bash
# cat ~/.local/share/jupyter/kernels/cmns-core/kernel.json
# ```
#
# The first entry under `argv` must be `/courses/NETS7052.202710/shared/cmns-core/bin/python`.
#
# Then **reload the browser tab** (JupyterLab only reads the kernel list at page load), open a notebook, and choose **Kernel → Change Kernel → Python (cmns-core)**. The kernel name shows in the top-right corner.
#
# ```{warning}
# If a notebook fails with `ImportError: numpy.core.multiarray failed to import`, or a message about NumPy 1.x and 2.x, you are running the system Python instead of the class environment. Check the kernel in the top-right corner and switch it to **Python (cmns-core)**. To confirm which Python a notebook is using, run `import sys; print(sys.executable)` — it should print a path starting with `/courses/NETS7052.202710/shared/cmns-core/`.
# ```

# %% [markdown]
# _________

# %% [markdown]
# ***We're in!***
# ![](images/ood_jupyter.png)
#
# Now, navigate to this jupyter notebook, and get a feel for the notebooks, the folders, the files, etc. that you see.

# %% [markdown]
# ____________

# %% [markdown]
# ## Keeping Your Fork in Sync
# We're going to go through a series of steps to hopefully make updating the Github repo less of a pain in the butt in the long run!
#
# ### Setting up SSH Keys with GitHub
# First we're going to set up SSH keys on Explorer and put them on GitHub. This lets us authenticate our identity to GitHub and makes it possible for us to push our changed code to our forked repository. Neat! First, let's follow the tutorial [here](https://docs.github.com/en/authentication/connecting-to-github-with-ssh/generating-a-new-ssh-key-and-adding-it-to-the-ssh-agent) to create SSH keys, because they explain it way better than I can.
#
# Then you'll add your **public SSH key** (the file that ends in `.pub`) to GitHub using [these instructions](https://docs.github.com/en/authentication/connecting-to-github-with-ssh/adding-a-new-ssh-key-to-your-github-account). Label them something memorable, like `explorer key`, so you'll know which machine(s) it's attached to.
#
# One more step, or that key just sits there doing nothing. You cloned your fork over HTTPS — that's what the green `Code` button hands you — and GitHub stopped accepting passwords over HTTPS in 2021, so pushing to an HTTPS remote fails no matter how many keys you've made. Point `origin` at the SSH address:
#
# `git remote set-url origin git@github.com:YOUR-GITHUB-USERNAME/nets7052_fa26.git`
#
# That's your **GitHub** username, not your NU one. Check it took with `git remote -v` — `origin` should now start with `git@github.com:`, and `upstream` should still be the `https://` address. Leave it that way; we only ever read from upstream, and reading doesn't need a key.
#
# Then ask GitHub who it thinks you are:
#
# `ssh -T git@github.com`
#
# First time it'll ask whether you trust `github.com` — type `yes`. You should get back `Hi YOUR-GITHUB-USERNAME! You've successfully authenticated...`. It also says GitHub doesn't provide shell access; that's expected, not an error.

# %% [markdown]
# ### Syncing the Fork
# Now we're going to sync our forked repository with the main student repository that I own. We can do this on GitHub, which is neat! This pulls in any changes I have made to the class repository since you forked it. Go to your forked repository on GitHub; you'll see a button that says `Sync fork`. Click on that; your screen should look something like this.
#
# ![](images/sync_fork.png)
#
# Click the green button (`Update branch`) to sync your fork with the main repository. Don't discard any commits you may have made.
#
# Careful though — that button updated your fork *on GitHub*. Your copy on Explorer hasn't heard about any of it. Back in the terminal:
#
# `cd nets7052_fa26`
#
# `git checkout main`
#
# `git pull origin main`
#
# So that's two routes to the same place: the `Sync fork` button then `git pull origin main`, or the `git fetch upstream` / `git merge upstream/main` pair from earlier. The upstream pair is the one to run before each class — it goes straight from my repo to your copy on Explorer and skips the button entirely.

# %% [markdown]
# __________

# %% [markdown]
# ## Check your setup
#
# Run the cell below. If it prints version numbers and draws a graph, your environment is working and you are ready for Class 1.
#
# If it fails, the error tells you what went wrong:
#
# - **`ImportError: numpy.core.multiarray failed to import`**, or any message about NumPy 1.x and 2.x — you are on the system Python, not the class environment. This is the most common failure. Check the kernel name in the top-right corner; if it is not **Python (cmns-core)**, switch it and then *Kernel → Restart Kernel*. If it already says `cmns-core`, the kernel was registered against the wrong interpreter: redo the registration step above using the full path, then reload the tab.
# - **`ModuleNotFoundError`** — the kernel is right but the package is missing. Tell me which package; it may need adding to the shared environment.
# - **Nothing happens / no output** — the kernel may have died or the session expired. *Kernel → Restart Kernel*, and check your session is still running under **My Interactive Sessions**.
#
# Ask now, in class, rather than discovering it on Monday.

# %%
# Smoke test: if this runs, your environment is set up correctly.
import sys

import matplotlib
import matplotlib.pyplot as plt
import networkx as nx
import numpy as np
import pandas as pd
import sklearn
import statsmodels

print("python     :", sys.version.split()[0])
print("numpy      :", np.__version__)
print("pandas     :", pd.__version__)
print("networkx   :", nx.__version__)
print("matplotlib :", matplotlib.__version__)
print("sklearn    :", sklearn.__version__)
print("statsmodels:", statsmodels.__version__)

G = nx.karate_club_graph()
print(f"\nZachary karate club: {G.number_of_nodes()} nodes, {G.number_of_edges()} edges")

fig, ax = plt.subplots(figsize=(4.5, 3.5))
nx.draw_spring(G, node_size=70, node_color="#0e7a9d", edge_color="#b8ccd4",
               width=0.8, ax=ax)
ax.set_title("If you can see this graph, you're all set.", fontsize=10)
ax.set_axis_off()
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Next time...
# Python refresher! `class_01_python_refresher.ipynb`

# %% [markdown]
# _________

# %% [markdown]
# ## References and further resources:
#
# 1. Class Webpages
#     - Jupyter Book: https://computational-methods-network-science.github.io/nets7052_fa26/README.html
#     - Github: https://github.com/computational-methods-network-science/nets7052_fa26/
#     - Syllabus and course details: https://brennanklein.com/nets7052-fall26
# 2. Explorer Cluster "OOD": https://ood.explorer.northeastern.edu/
#     - Open OnDemand Documentation: https://osc.github.io/ood-documentation/latest/
# 3. **Python for R users:** https://rebeccabarter.com/blog/2023-09-11-from_r_to_python

# %% [markdown]
# _________________
